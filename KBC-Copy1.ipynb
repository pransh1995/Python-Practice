# %%
import numpy as np
import pandas as pd
import time
from random import randint

# %% [markdown]
# ### CODE

# %%
### Question Bank
question_bank = {'Questions': ['The International Literacy Day is observed on?',
                               'The language of Lakshadweep, A Union Territory of India, is',
                              'Which party was founded by Sampat Pal Devi to prevent violence against women in Bundelkhand?',
                              'Bahubali festival is related to',
                              'Which day is observed as the World Standards  Day?',
                              'Good Friday is observed to commemorate the event of',
                              'Who is the author of the book Amrit Ki Ore?',
                              'Which of the following is observed as Sports Day every year?',
                              'World Health Day is observed on?',
                              'Ghototkach in Mahabharat was the son of?',
                              'Van Mahotsav was started by?',
                              'The first month of the Indian national calendar is?',
                              'Which of the following is not a dance from Kerala?'],
                 'Options': ['A. Sep 8,B. Nov 28,C. May 2,D. Sep 22', 
                             'A. Tamil,B. Hindi,C. Malayalam,D. Telugu',
                            'A. Laxmibai Army,B. Pink Gang,C. Nari Mukti Vahini,D. Mahila Morcha',
                            'A. Islam,B. Hinduism,C. Buddhism,D. Jainism',
                            'A. June 26,B. Oct 14,C. Nov 15,D. Dec 2',
                            'A. birth of Jesus Christ,B. birth of St. Peter,C. crucification of Jesus Christ,D. rebirth of Jesus Christ',
                            'A. Mukesh Kumar,B. Narendra Mohan,C. Upendra Nath,D. Nirad C. Choudhary',
                            'A. 22nd April,B. 26th  july,C. 29th August,D. 2nd October',
                            'A. Apr 7,B. Mar 6,C. Mat I5,D. Apr 28',
                            'A. Duryodhana,B. Arjuna,C. Yudhishthir,D. Bhima',
                            'A. Maharshi Karve,B. Bal Gangadhar Tiiak,C. K.M Munshi,D. Sanjay Gandhi',
                            'A. Magha,B. Chaitra,C. Ashadha,D. Vaishakha',
                            'A. Kathakali,B. Mohiniattam,C. Ottan Thullal,D. Yaksha Gana'],
                 'Answers' : ['A','C','B','D','B','C','B','C','A','D','C','C','D']}
rupees = [0,1000,5000,10000,20000,40000,80000,160000,320000,640000,1250000,2500000,5000000,10000000]

## Creating Dataframe from the Dictionary
x = pd.DataFrame(question_bank)
x.head()



######################################### CODE ###########################################

print('##########------------ Welcome to Kaun Banega Crorepati ------------########## ')
print('\n')
print('   ##########------------       Shall We Start       ------------##########')

# Defining a Counter to retireve amount won from the rupee list.
c = 0

# Taking Input from the user to start the game or not
print('\n')
ans = (input('Answer Only in Y or N: ')).upper()
print('\n')
if ans == 'N':
    print('You dont wish to continue, Good Luck.')
    print('\n')
else:
    print('Get Ready.. We are about to start!!!')
    print('\n')
    go = ['>>>> GO <<<<','1','2','3']
    t3=4
    while t3:
        mins, secs = divmod(t3,60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        print('                    ',go[t3-1],end='\r')
        time.sleep(1)
        t3-=1
    print('---------------------------------------------------------------------')
    print('---------------------------------------------------------------------')
    t=1
    while t:
            mins, secs = divmod(t,60)
            timer = '{:02d}:{:02d}'.format(mins, secs)
            time.sleep(1)
            t-=1
    for i in range(len(x['Questions'])):
        print('---------------------------------------------------------------------')
        print('\n')
        print(str(i+1),' Question On Your Computer Screen')
        print('\n')
        t=1
        while t:
            mins, secs = divmod(t,60)
            timer = '{:02d}:{:02d}'.format(mins, secs)
            time.sleep(1)
            t-=1
        
        # For printing Options after 10 seconds so that player can have time to read.
        ind = randint(0,len(x['Questions']))
        print(x['Questions'][ind])
        print('\n')
        t=10
        while t:
            mins, secs = divmod(t,60)
            timer = '{:02d}:{:02d}'.format(mins, secs)
            time.sleep(1)
            t-=1
        print('------- Your Options Are -------')
        print('\n')
        t1=2
        while t1:
            mins, secs = divmod(t1,60)
            timer = '{:02d}:{:02d}'.format(mins, secs)
            time.sleep(1)
            t1-=1
        l=0
        n=0
        for j in x['Options'][ind].split(','):
            if l<2:
                print(j, end='           ')
                t2=2
                while t2:
                    mins, secs = divmod(t2,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t2-=1
                l+=1
            else:
                if n==0:
                    print('\n')
                    n+=1
                print(j, end='        ')
                t3=2
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                l+=1
        print('\n')
        print('Enter your Option: ',end='  ')
        answer = (input('')).upper()
        print('\n')
        
        t3=3
        while t3:
            mins, secs = divmod(t3,60)
            timer = '{:02d}:{:02d}'.format(mins, secs)
            time.sleep(1)
            t3-=1
        print('Kya Lagta hai... Sahi hoga!!')
        t3=2
        while t3:
            mins, secs = divmod(t3,60)
            timer = '{:02d}:{:02d}'.format(mins, secs)
            time.sleep(1)
            t3-=1
        print('\n')    
        # checking the answer
            
        if answer == x['Answers'][ind]:
            c+=1
            print('......................... Sahi Jawaab .........................')
            print('\n')
            t3=1
            while t3:
                mins, secs = divmod(t3,60)
                timer = '{:02d}:{:02d}'.format(mins, secs)
                time.sleep(1)
                t3-=1
            print('AAP JEET CHUKE HAIN POORE',rupees[c],'RUPEES')
            print('______________________________________________________________')
            print('______________________________________________________________')
            
            
            # Removing the Asked quesrion from the Question Bank dataframe(x)
            # And resetting the default index from 0.
            # Also dropping the indexes to avoid duplicate indexes in the data.
            x.drop(index=ind,axis=0,inplace=True)
            x.reset_index(inplace=True)
            x.drop('index',axis=1,inplace=True)
            
            t3=3
            while t3:
                mins, secs = divmod(t3,60)
                timer = '{:02d}:{:02d}'.format(mins, secs)
                time.sleep(1)
                t3-=1
            print('\n')
            print('Agla Question Aapke Computer Screen pe hai ye')
            t3=2
            while t3:
                mins, secs = divmod(t3,60)
                timer = '{:02d}:{:02d}'.format(mins, secs)
                time.sleep(1)
                t3-=1
                
                
                
        else:
            if c==0:
                print('--------------------- AFSOOS YE GALAT JAWAAB HAI ---------------------')
                print('\n')
                t3=2
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                
                print('---------------- BHAGYASHALI NAHI RAHE AAP BILKUL BHI ----------------')
                print('\n')
                t3=2
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                print('-------------- AAPKO YAHAN SE KHALI HAATH LAUTNA PADEGA --------------')
                print('\n')
                t3=1
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                print('---------- PAR HAUSLA MAT KHOYEGA... ----------',end=' ')
                t3=1
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                print('LAGE RAHIYE..')
                print('\n')
                t3=1
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                print('------------ KOSHISH KARNE WALON KI KABHI HAAR NAHI HOTI ------------')
                print('\n')
                
                
            else:
                print('-------------------- AFSOOS YE GALAT JAWAAB HAI ---------------------')
                print('\n')
                t3=2
                while t3:
                    mins, secs = divmod(t3,60)
                    timer = '{:02d}:{:02d}'.format(mins, secs)
                    time.sleep(1)
                    t3-=1
                print('--------------------- BOHOT HI UNDA KHELE AAP -----------------------')
                print('\n')
            break

if c==0:
    t3=1
    while t3:
        mins, secs = divmod(t3,60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        time.sleep(1)
        t3-=1
    print('##########------------ Ye Show yahin Samapt Hota hai ------------##########')
    
else:
    print('###########################################################################')
    print('\n')
    t3=1
    while t3:
        mins, secs = divmod(t3,60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        time.sleep(1)
        t3-=1
    print('App Jeet Chuke Hain Pure',rupees[c],'Rupees')
    print('\n')
    t3=1
    while t3:
        mins, secs = divmod(t3,60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        time.sleep(1)
        t3-=1
    print('##########------------ Ye Show yahin Samapt Hota hai ------------##########')
# Out:
# ##########------------ Welcome to Kaun Banega Crorepati ------------##########
#
#
#    ##########------------       Shall We Start       ------------##########
#
#
# Answer Only in Y or N: n
#
#
# You dont wish to continue, Good Luck.
#
#
# ##########------------ Ye Show yahin Samapt Hota hai ------------##########
